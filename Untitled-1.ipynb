# %%
import torch
from gwemlightcurves.KNModels import KNTable

# %%
t = KNTable.read_mchirp_samples('posterior_samples.dat')
# Out:
# ---------------------------------------------------------------------------
# InconsistentTableError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     463             reader = get_reader(**read_kwargs)
# --> 464             dat = reader.read(table)
#     465             _read_trace.append({'kwargs': copy.deepcopy(read_kwargs),
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/ascii/core.py in read(self, table)
#    1197         # Make sure columns are valid
# -> 1198         self.header.check_column_names(self.names, self.strict_names, self.guessing)
#    1199
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/ascii/core.py in check_column_names(self, names, strict_names, guessing)
#     676         if names is not None and len(names) != len(self.colnames):
# --> 677             raise InconsistentTableError(
# ...
