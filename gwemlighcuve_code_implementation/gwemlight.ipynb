# %% [markdown]
# The packages pytorch and lalsim had not been installed. Therefore, I intalled them personlly. A conda environment was created, and pytorch and lalsuite were installed by these commands.
#
# **Pythorch:** `pip install torch==1.8.1+cpu torchvision==0.9.1+cpu torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html`
#
# **lalsuite:** `conda install -c conda-forge lalsuite`
#
# Now the package is completely usable.

# %%
import matplotlib.pyplot as plt
from gwpy.table import EventTable

# %%
from gwemlightcurves.KNModels import KNTable
t = KNTable.read_samples('posterior_samples.dat')
# Out:
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# /home/pouyan/anaconda3/envs/torch/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# /home/pouyan/anaconda3/envs/torch/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# You are requesting to downsample the number of posterior samples to 100

# %%
tkeys= list(t.keys())
print('The number of measured variables are: %d'%(len(tkeys)))
print(type(t))
t
# Out:
# The number of measured variables are: 93
# <class 'gwemlightcurves.KNModels.table.KNTable'>
# <KNTable length=100>
#     chirp_mass         mass_ratio     ...         q          chi_eff
#      float64            float64       ...      float64       float64
# ------------------ ------------------ ... ------------------ -------
#  1.197652851551103 0.8939470971385758 ... 1.1186344283692935     0.0
# 1.1976021977424176 0.9217047909076707 ... 1.0849460802034305     0.0
# 1.1977355801058516 0.8420949194625147 ...  1.187514586405855     0.0
#  1.197597845237006  0.679787346606833 ... 1.4710482697148046     0.0
# 1.1977119563971323 0.7045517751770723 ... 1.4193421054807132     0.0
# 1.1976643809457006 0.8431992649620428 ... 1.1859592880990186     0.0
# 1.1977379979333047 0.7201884765173783 ...    1.3885254105088     0.0
# 1.1976678976215285 0.9608110139429973 ... 1.0407874030254691     0.0
# 1.1977105568292121 0.8048135430751093 ... 1.2425238225727455     0.0
# 1.1976860375737874 0.7994185803390057 ... 1.2509091289521124     0.0
#                ...                ... ...                ...     ...
# 1.1977446340757725 0.7008179366280671 ... 1.4269041183669255     0.0
#   1.19763827379011 0.8775904938196802 ... 1.1394836282324994     0.0
# 1.1975078911105252 0.8966670654248429 ... 1.1152411397269262     0.0
# 1.1976278871879338 0.9625492282393064 ... 1.0389079027461259     0.0
# 1.1975687571906215 0.9309357829823333 ... 1.0741879496740512     0.0
# 1.1975670088492372 0.8577651676737754 ... 1.1658202474133563     0.0
# 1.1975605832231508 0.8138026372347573 ... 1.2287991636374245     0.0
# 1.1975736736071037 0.8591716147891943 ...  1.163911822488874     0.0
# 1.1977786372290722 0.9305475851570272 ...  1.074636070149226     0.0
# 1.1976585102347836  0.981079003871142 ... 1.0192859046561995     0.0

# %% [markdown]
# Points to mention about the point above:
# - How to have the shape of the KNTable.
# - How to filter KNTalbes.
# - What are lambda and lambda_tilde

# %%
t = t.calc_tidal_lambda(remove_negative_lambda=True)
# Out:
# You have requested to remove negative lambda values
# Removing 0/100 due to negative lambdas

# %%
t_sly_mon = t.calc_radius(EOS='sly', TOV='Monica')
t_sly_lalsim = t.calc_radius(EOS='sly', TOV='lalsim')

# %% [markdown]
# As it was discussed, only lalsim is the valid method for TOV these day.

# %%
t_sly_mon = t_sly_mon.calc_compactness()
t_sly_lalsim = t_sly_lalsim.calc_compactness()
# Out:
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS

# %% [markdown]
# Unfortunately, lalsim compactness function needs some arguments. The input format of the arguments is unknown. Subsequently, we cannot use

# %%
t_sly_Monica = t_sly_lalsim.calc_baryonic_mass(EOS='ap4', TOV='Monica')

# %% [markdown]
# Apparently, lalsim has not been defined in the TOV list. Therefore, the baryoni_mass function cannot be run.

# %%
t_sly_lalsim = t_sly_lalsim.calc_baryonic_mass(EOS='ap4', TOV='lalsim')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-db3396242b72> in <module>
# ----> 1 t_sly_lalsim = t_sly_lalsim.calc_baryonic_mass(EOS='ap4', TOV='lalsim')
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/gwemlightcurves/KNModels/table.py in calc_baryonic_mass(self, EOS, TOV, fit)
#     724
#     725         if TOV not in ['Monica', 'Wolfgang']:
# --> 726             raise ValueError('You have provided a TOV '
#     727                              'for which we have no data '
#     728                              'and therefore cannot '
#
# ValueError: You have provided a TOV for which we have no data and therefore cannot calculate the Baryonic mass.

# %%
ax = plt.gca()
EOS = ['ap3', 'ap4', 'eng', 'gnh3', 'H4', 'mpa1', 'ms1', 'ms1b', 'sly', 'wff1', 'wff2']
Color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'chartreuse', 'burlywood', 'lightseagreen', 'mediumaquamarine', 'brown']
EOS_Color = dict(zip(EOS, Color))

# %%
for eos in EOS:
    t_radius = t.calc_radius(EOS=eos, TOV='Monica')
    t_radius_compact = t_radius.calc_compactness()
    t_radius_compact = EventTable(t_radius_compact)
    ax.hist(t_radius_compact['c1'], log=True, bins=20, alpha=0.5, histtype='stepfilled', label='Compactness From {0} Table'.format(eos), color=EOS_Color[eos])
# Out:
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS

# %%
ax.set_xlabel('Compactness')
ax.set_ylabel('Rate')
ax.set_title('Compactness Values')
plt.legend()
ax.autoscale(axis='x', tight=True)
plt.show()
# Out:
# <ipython-input-12-9f3acad28513>:6: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
