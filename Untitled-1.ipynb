# %%
import torch
from gwemlightcurves.KNModels import KNTable
from gwemlightcurves import lightcurve_utils
t = KNTable.read_samples('docs/examples/posterior_samples.dat')
t = t.calc_tidal_lambda(remove_negative_lambda=True)
# Out:
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# /home/pouyan/anaconda3/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# /home/pouyan/anaconda3/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# You are requesting to downsample the number of posterior samples to 100
# You have requested to remove negative lambda values
# Removing 0/100 due to negative lambdas

# %% [markdown]
# ## Question!!!!
# - Does the case sensetive triggers for the functions are important or not?
# - Wolfgang function doesn't work

# %%
t = t.calc_compactness(fit=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Codes/gwemlightcurves/gwemlightcurves/KNModels/table.py in calc_compactness(self, fit)
#     676         try:
# --> 677             import lal
#     678             G = lal.G_SI; c = lal.C_SI; msun = lal.MSUN_SI
#
# ModuleNotFoundError: No module named 'lal'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-39-ddecc7bda661> in <module>
# ----> 1 t = t.calc_compactness(fit=True)
#
# ~/Codes/gwemlightcurves/gwemlightcurves/KNModels/table.py in calc_compactness(self, fit)
#     680             import astropy.units as u
#     681             import astropy.constants as C
# --> 682             G = lal.G_SI; c = C.c.value; msun = u.M_sun.to(u.kg)
#     683
#     684         if fit:
#
# ...
