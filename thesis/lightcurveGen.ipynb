# %%
from gwemlightcurves.KNModels import KNTable
from gwemlightcurves import lightcurve_utils

# %%
t = KNTable.read_samples('posterior_samples.dat')
# Out:
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# /home/pouyan/anaconda3/envs/thesis/lib/python3.9/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# /home/pouyan/anaconda3/envs/thesis/lib/python3.9/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# You are requesting to downsample the number of posterior samples to 100

# %%
t = t.calc_tidal_lambda(remove_negative_lambda=True)
t_sly_lalsim = t.calc_radius(EOS='sly', TOV='lalsim')
# Out:
# You have requested to remove negative lambda values
# Removing 0/100 due to negative lambdas
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/gwemlightcurves-0.0.2+6.g24e2c6d-py3.9.egg/gwemlightcurves/KNModels/table.py in get_eos_list(TOV)
#     192         path = find_executable('ap4_mr.dat')
# --> 193         path = path[:-10]
#     194     except:
#
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-6c8f8fc3e164> in <module>
#       1 t = t.calc_tidal_lambda(remove_negative_lambda=True)
# ----> 2 t_sly_lalsim = t.calc_radius(EOS='sly', TOV='lalsim')
#
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/gwemlightcurves-0.0.2+6.g24e2c6d-py3.9.egg/gwemlightcurves/KNModels/table.py in calc_radius(self, EOS, TOV, polytrope)
#     766                              'calculate the radius.')
#     767
# --> 768         if EOS not in get_eos_list(TOV):
#     769             raise ValueError('You have provided a EOS '
#     770                             'for which we have no data '
#
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/gwemlightcurves-0.0.2+6.g24e2c6d-py3.9.egg/gwemlightcurves/KNModels/table.py in get_eos_list(TOV)
#     193         path = path[:-10]
#     194     except:
# --> 195        raise ValueError('Check to make sure EOS mass-radius '
#     196                         'tables have been installed correctly '
#     197                         '(try `which ap4_mr.dat`)')
#
# ValueError: Check to make sure EOS mass-radius tables have been installed correctly (try `which ap4_mr.dat`)

# %%
t = t.calc_compactness()
# Out:
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-0c68ebd3cb05> in <module>
# ----> 1 t = t.calc_compactness()
#
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/gwemlightcurves-0.0.2+6.g24e2c6d-py3.9.egg/gwemlightcurves/KNModels/table.py in calc_compactness(self, fit)
#     690             print('You have chose to calculate compactness from radius.')
#     691             print('you are therefore must have selected a EOS')
# --> 692             self['c1'] = self['m1'] / self['r1'] * G / c**2 * msun
#     693             self['c2'] = self['m2'] / self['r2'] * G / c**2 * msun
#     694
#
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1652     def __getitem__(self, item):
#    1653         if isinstance(item, str):
# -> 1654             return self.columns[item]
#    1655         elif isinstance(item, (int, np.integer)):
#    1656             return self.Row(self, item)
#
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/astropy/table/table.py in __getitem__(self, item)
#     237         """
#     238         if isinstance(item, str):
# --> 239             return OrderedDict.__getitem__(self, item)
#     240         elif isinstance(item, (int, np.integer)):
#     241             return list(self.values())[item]
#
# KeyError: 'r1'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/gwemlightcurves-0.0.2+6.g24e2c6d-py3.9.egg/gwemlightcurves/KNModels/table.py in get_eos_list(TOV)
#     192         path = find_executable('ap4_mr.dat')
# --> 193         path = path[:-10]
#     194     except:
#
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-baf12ff4ee2e> in <module>
# ----> 1 KNTable.calc_baryonic_mass(t, EOS='sly', TOV='Monica', fit=False)
#
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/gwemlightcurves-0.0.2+6.g24e2c6d-py3.9.egg/gwemlightcurves/KNModels/table.py in calc_baryonic_mass(self, EOS, TOV, fit)
#     729                              'calculate the Baryonic mass.')
#     730
# --> 731         if EOS not in get_eos_list(TOV):
#     732             raise ValueError('You have provided a EOS '
#     733                             'for which we have no data '
#
# ~/anaconda3/envs/thesis/lib/python3.9/site-packages/gwemlightcurves-0.0.2+6.g24e2c6d-py3.9.egg/gwemlightcurves/KNModels/table.py in get_eos_list(TOV)
#     193         path = path[:-10]
#     194     except:
# --> 195        raise ValueError('Check to make sure EOS mass-radius '
#     196                         'tables have been installed correctly '
#     197                         '(try `which ap4_mr.dat`)')
#
# ValueError: Check to make sure EOS mass-radius tables have been installed correctly (try `which ap4_mr.dat`)
