# %% [markdown]
# ## Table of Contents
#
# ### <span style="color:green"> 1) Simulating a Kilonova Lightcurve</span>
# - Introduction
# - Reading and using KNTable
# - Calculating Compactness
# - Calculating Baryonic Mass
# - Calculating Ejecta Mass and Velocity of Ejecta
# - Generating Light Curves
#
# ### <span style="color:orange"> 2) Lightcurves </span>
# - Introduction
# - Brian Metzger
# - Wollaeger
# - Tim Dietrich and Maximiliano Ujevic
#
# ### <span style="color:red"> 3) Equation of State </span>
# - Introduction
# - Mass-Radius Curves
# - Maximum NS Mass
# - EOS From Polytropes
# - Direct Comparison

# %% [markdown]
# # <span style="color:green"> 1) Simulating a Kilonova Lightcurve</span>

# %% [markdown]
# When attempting to simulate the lightcurve from a kilonova assosciated with a binary coalesence, a number of parameters must be determine first:
# - Firstly, determine if the system is a BNS or a NSBH system (which fit model should be used)
# - Fit model will compute
#   > the expected dynamical ejecta mass <br>
#   > dynamical ejecta velocity .. that arises from the system.
#
# For binary neutron stars, one can use Tim Dietrich and Maximiliano Ujevic, and for a NSBH one can use Kawaguchi.
#
# These fits tie information such as:
# - compactness,
# - baryonic mass,
# - mass of the objects to the expected ejecta
#
# These fits come with uncertainities of ~72% but **knowing the ejecta mass is critical when determining the expected lightcurve from the resulting kilonova.**
#
# We now explain how one can go from a set of posteriors of the system to generating the expected lightcurve from the kilonova. We consider many important things including:
# - whether or not you make Equation of State (EOS) assumptions
# - whether or not you use fits for compactness and baryonic mass, and
# - how you treat the uncertainity in ejecta that comes with the fit.

# %% [markdown]
# #### 1.1) Reading and using KNTable

# %% [markdown]
# The KNTable object comes with a `read_samples()`, allowing trivial reading of samples:

# %%
# !pip install git+https://github.com/mcoughlin/gwemlightcurves
# Out:
# Collecting git+https://github.com/mcoughlin/gwemlightcurves
#   Cloning https://github.com/mcoughlin/gwemlightcurves to /tmp/pip-req-build-_6en5wsh
#   Running command git clone -q https://github.com/mcoughlin/gwemlightcurves /tmp/pip-req-build-_6en5wsh
# Requirement already satisfied: numpy in /home/pouyan/anaconda3/envs/torch/lib/python3.8/site-packages (from gwemlightcurves==0+untagged.425.ga91d4ab) (1.20.1)
# Requirement already satisfied: scipy in /home/pouyan/anaconda3/envs/torch/lib/python3.8/site-packages (from gwemlightcurves==0+untagged.425.ga91d4ab) (1.6.2)
# Requirement already satisfied: astropy in /home/pouyan/anaconda3/envs/torch/lib/python3.8/site-packages (from gwemlightcurves==0+untagged.425.ga91d4ab) (4.2)
# Requirement already satisfied: h5py in /home/pouyan/anaconda3/envs/torch/lib/python3.8/site-packages (from gwemlightcurves==0+untagged.425.ga91d4ab) (3.2.1)
# Collecting pandas
#   Downloading pandas-1.2.3-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#      |███████████████▏                | 4.6 MB 867 kB/s eta 0:00:06

# %%
from gwemlightcurves.KNModels import KNTable
t = KNTable.read_samples('posterior_samples.dat')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6ae5f8040645> in <module>
# ----> 1 from gwemlightcurves.KNModels import KNTable
#       2 t = KNTable.read_samples('posterior_samples.dat')
#
# ModuleNotFoundError: No module named 'gwemlightcurves'

# %%
t
# Out:
# <KNTable length=35392>
#     chirp_mass         mass_ratio     ...         q          chi_eff
#      float64            float64       ...      float64       float64
# ------------------ ------------------ ... ------------------ -------
# 1.1976132771415884 0.8570731407826855 ... 1.1667615660978392     0.0
#  1.197558884773613 0.9588427941239721 ... 1.0429238308179918     0.0
# 1.1976058636220297 0.8332131586429111 ... 1.2001730765135075     0.0
# 1.1976087016348054 0.9607416101483752 ... 1.0408625893132304     0.0
# 1.1976795248898326 0.9987750971281013 ... 1.0012264050990267     0.0
#  1.197634915434856 0.8155622775123004 ... 1.2261479320135893     0.0
# 1.1976075477610117 0.9854194365620921 ... 1.0147963018557624     0.0
# 1.1976774991576093 0.7941478013312475 ...  1.259211444423416     0.0
# 1.1976001457972234 0.6955660434047215 ... 1.4376780026596852     0.0
# 1.1975582662169957 0.8207881389707098 ... 1.2183411924714538     0.0
#                ...                ... ...                ...     ...
# 1.1975490049215385 0.9506047687209491 ... 1.0519619014172554     0.0
# 1.1976833782379415 0.8061246468166303 ... 1.2405029469685356     0.0
# 1.1976021988052235 0.8820705387216288 ... 1.1336961797287601     0.0
# 1.1977655120447779 0.9463631583852118 ... 1.0566768065087289     0.0
# 1.1977579974274781 0.8540497632510055 ... 1.1708919585592108     0.0
# 1.1974894196376875 0.9248939307585715 ... 1.0812050622711176     0.0
# 1.1975242265390316 0.9833959974224095 ... 1.0168843503747336     0.0
# 1.1976093294828807 0.7262608815361089 ... 1.3769156861166851     0.0
# 1.1976742244336531 0.8349179674768509 ... 1.1977224577188492     0.0
# 1.1976670152805464 0.8521952925622986 ...  1.173439948246248     0.0

# %% [markdown]
# After loading the table, one can caluclate **lambda1 and lambda2** from **dtilde** if it is not already in the samples. `calc_tidal_lambda()`:

# %%
l = t.calc_tidal_lambda(remove_negative_lambda=True)
# Out:
# You have requested to remove negative lambda values
# Removing 0/35392 due to negative lambdas

# %%
# lambda 1 and 2 in last two columns
l
# Out:
# <KNTable length=35392>
#     chirp_mass         mass_ratio     ...      lambda1            lambda2
#      float64            float64       ...      float64            float64
# ------------------ ------------------ ... ------------------ ------------------
# 1.1976132771415884 0.8570731407826855 ... 232.53120793343015  582.4139943289425
#  1.197558884773613 0.9588427941239721 ... 193.87161769920712 243.36943076631204
# 1.1976058636220297 0.8332131586429111 ...    323.96130796382  878.5246777576373
# 1.1976087016348054 0.9607416101483752 ... 276.96445673575323  351.4616851719922
# 1.1976795248898326 0.9987750971281013 ...  406.4210027502942  409.1329651684502
#  1.197634915434856 0.8155622775123004 ...  153.0642273623655 511.98943020406995
# 1.1976075477610117 0.9854194365620921 ...  287.2148217541092  309.9964595911721
# 1.1976774991576093 0.7941478013312475 ...  269.8742641969934  900.7806585078624
# 1.1976001457972234 0.6955660434047215 ... 50.008954255559544  432.5944824322484
# 1.1975582662169957 0.8207881389707098 ... 109.40691450402781 378.02512260098547
#                ...                ... ...                ...                ...
# 1.1975490049215385 0.9506047687209491 ...  207.7781293564539  299.5957407233302
# 1.1976833782379415 0.8061246468166303 ... 162.61361957371233  583.1507758780865
# 1.1976021988052235 0.8820705387216288 ...  278.0773781283038  575.7458996571943
# 1.1977655120447779 0.9463631583852118 ...   742.278766382562   960.570489945684
# 1.1977579974274781 0.8540497632510055 ...  528.6560489591302 1131.2349764562034
# 1.1974894196376875 0.9248939307585715 ...  250.2542602013951  397.1116644159514
# 1.1975242265390316 0.9833959974224095 ...   466.531810489974  514.8907161664473
# 1.1976093294828807 0.7262608815361089 ...  86.68548375765472  642.0091606383028
# 1.1976742244336531 0.8349179674768509 ... 150.32060361403998 444.93466287932785
# 1.1976670152805464 0.8521952925622986 ... 260.73551213265034  681.6389610544222

# %% [markdown]
# After accomplishing the reading of the sample, let’s say we want to **calculate compactness from radius**. This would **require calculating the radius from a mass radius curve**. We can use `gwemlightcurves.KNModels.KNTable.calc_radius()`. In this module we have a number of ways to accomplish this:

# %%
t_sly_mon = t.calc_radius(EOS='sly', TOV='Monica')
t_sly_lalsim = t.calc_radius(EOS='sly', TOV='lalsim')

#not working in documentation 
#t_sly_wolf = t.calc_radius(EOS='sly', TOV='Wolfgang')

# %%
# creates 2 columns, that contain r1 and r2
t_sly_mon
# Out:
# <KNTable length=35392>
#     chirp_mass         mass_ratio     ...         r1                 r2
#      float64            float64       ...      float64            float64
# ------------------ ------------------ ... ------------------ ------------------
# 1.1976132771415884 0.8570731407826855 ... 11777.389657061398 11916.029518707363
#  1.197558884773613 0.9588427941239721 ... 11835.682880406244  11873.05571954135
# 1.1976058636220297 0.8332131586429111 ... 11759.072818840823 11924.834855250343
# 1.1976087016348054 0.9607416101483752 ... 11837.679736336288 11873.133099351273
# 1.1976795248898326 0.9987750971281013 ... 11856.392640692848 11857.474879637546
#  1.197634915434856 0.8155622775123004 ...  11746.13484967732 11932.063679881096
# 1.1976075477610117 0.9854194365620921 ... 11851.505687217837 11864.373879423862
# 1.1976774991576093 0.7941478013312475 ... 11725.470709719253 11939.125178471837
# 1.1976001457972234 0.6955660434047215 ... 11605.221792129409 11972.753312909519
# 1.1975582662169957 0.8207881389707098 ...  11749.83083167933   11929.8292490112
#                ...                ... ...                ...                ...
# 1.1975490049215385 0.9506047687209491 ...  11833.96304174631  11878.58533193544
# 1.1976833782379415 0.8061246468166303 ... 11733.742750720785 11933.669319693216
# 1.1976021988052235 0.8820705387216288 ... 11793.736931404466 11905.933635145857
# 1.1977655120447779 0.9463631583852118 ... 11827.950205532477 11877.274483796582
# 1.1977579974274781 0.8540497632510055 ...    11771.032752163 11914.922106246397
# 1.1974894196376875 0.9248939307585715 ... 11819.997977608904 11889.061232029297
# 1.1975242265390316 0.9833959974224095 ... 11849.403108586856 11864.147736647416
# 1.1976093294828807 0.7262608815361089 ... 11654.520276546347 11964.003909675208
# 1.1976742244336531 0.8349179674768509 ... 11758.566524708242 11923.285889674282
# 1.1976670152805464 0.8521952925622986 ... 11769.400289784126 11915.494312825542

# %%
t_sly_lalsim
# Out:
# <KNTable length=35392>
#     chirp_mass         mass_ratio     ...         r1                 r2
#      float64            float64       ...      float64            float64
# ------------------ ------------------ ... ------------------ ------------------
# 1.1976132771415884 0.8570731407826855 ... 11777.389657061398 11916.029518707363
#  1.197558884773613 0.9588427941239721 ... 11835.682880406244  11873.05571954135
# 1.1976058636220297 0.8332131586429111 ... 11759.072818840823 11924.834855250343
# 1.1976087016348054 0.9607416101483752 ... 11837.679736336288 11873.133099351273
# 1.1976795248898326 0.9987750971281013 ... 11856.392640692848 11857.474879637546
#  1.197634915434856 0.8155622775123004 ...  11746.13484967732 11932.063679881096
# 1.1976075477610117 0.9854194365620921 ... 11851.505687217837 11864.373879423862
# 1.1976774991576093 0.7941478013312475 ... 11725.470709719253 11939.125178471837
# 1.1976001457972234 0.6955660434047215 ... 11605.221792129409 11972.753312909519
# 1.1975582662169957 0.8207881389707098 ...  11749.83083167933   11929.8292490112
#                ...                ... ...                ...                ...
# 1.1975490049215385 0.9506047687209491 ...  11833.96304174631  11878.58533193544
# 1.1976833782379415 0.8061246468166303 ... 11733.742750720785 11933.669319693216
# 1.1976021988052235 0.8820705387216288 ... 11793.736931404466 11905.933635145857
# 1.1977655120447779 0.9463631583852118 ... 11827.950205532477 11877.274483796582
# 1.1977579974274781 0.8540497632510055 ...    11771.032752163 11914.922106246397
# 1.1974894196376875 0.9248939307585715 ... 11819.997977608904 11889.061232029297
# 1.1975242265390316 0.9833959974224095 ... 11849.403108586856 11864.147736647416
# 1.1976093294828807 0.7262608815361089 ... 11654.520276546347 11964.003909675208
# 1.1976742244336531 0.8349179674768509 ... 11758.566524708242 11923.285889674282
# 1.1976670152805464 0.8521952925622986 ... 11769.400289784126 11915.494312825542

# %% [markdown]
# After this we can now **calculate the compactness** `calc_compactness()`:

# %%
t_sly_mon = t_sly_mon.calc_compactness()
t_sly_lalsim = t_sly_lalsim.calc_compactness()
#t_sly_wolf = t_sly_wolf.calc_compactness()
# Out:
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS

# %%
t_sly_mon
# Out:
# <KNTable length=35392>
#     chirp_mass         mass_ratio     ...          c2
#      float64            float64       ...       float64
# ------------------ ------------------ ... -------------------
# 1.1976132771415884 0.8570731407826855 ... 0.15653591284361612
#  1.197558884773613 0.9588427941239721 ... 0.16654173487389268
# 1.1976058636220297 0.8332131586429111 ...  0.1543107132193433
# 1.1976087016348054 0.9607416101483752 ... 0.16652489492550313
# 1.1976795248898326 0.9987750971281013 ... 0.16985098388213413
#  1.197634915434856 0.8155622775123004 ... 0.15243551948096162
# 1.1976075477610117 0.9854194365620921 ...  0.1684039455851398
# 1.1976774991576093 0.7941478013312475 ... 0.15055954370468505
# 1.1976001457972234 0.6955660434047215 ... 0.14104601432417965
# 1.1975582662169957 0.8207881389707098 ... 0.15301875919047755
#                ...                ... ...                 ...
# 1.1975490049215385 0.9506047687209491 ... 0.16532625634883966
# 1.1976833782379415 0.8061246468166303 ...  0.1520127150062791
# 1.1976021988052235 0.8820705387216288 ... 0.15901129274628006
# 1.1977655120447779 0.9463631583852118 ...  0.1656154684876192
# 1.1977579974274781 0.8540497632510055 ...  0.1568123331699815
# 1.1974894196376875 0.9248939307585715 ...   0.162970708629044
# 1.1975242265390316 0.9833959974224095 ... 0.16845210174741707
# 1.1976093294828807 0.7262608815361089 ... 0.14361216034445218
# 1.1976742244336531 0.8349179674768509 ...  0.1547073899425273
# 1.1976670152805464 0.8521952925622986 ... 0.15666974639770645

# %% [markdown]
# After this we can **calulcate the baryonic mass**. Now we can either use the calculated compactness and have it be EOS dependent of calculate the baryonic mass using a fit using `calc_baryonic_mass()`:

# %%
t_sly_mon = t_sly_mon.calc_baryonic_mass(EOS='ap4', TOV='Monica')
#t_sly_wolf = t_sly_wolf.calc_baryonic_mass(EOS='ap4', TOV='Wolfgang')
#t_sly_lalsim = t_sly_lalsim.calc_baryonic_mass(EOS='ap4', TOV='lalsim')

# fit version
t_sly_mon_bary_from_fit = t_sly_mon.calc_baryonic_mass(EOS='None', TOV='None', fit=True)

# %%
t_sly_mon
# Out:
# <KNTable length=35392>
#     chirp_mass         mass_ratio     ...        mb1                mb2
#      float64            float64       ...      float64            float64
# ------------------ ------------------ ... ------------------ ------------------
# 1.1976132771415884 0.8570731407826855 ... 1.6435942165516335 1.3822527903789363
#  1.197558884773613 0.9588427941239721 ... 1.5463891629881912  1.475113261129336
# 1.1976058636220297 0.8332131586429111 ... 1.6712656535358834 1.3615965434884902
# 1.1976087016348054 0.9607416101483752 ... 1.5427825251002256 1.4749571027339712
# 1.1976795248898326 0.9987750971281013 ...  1.507855589985098 1.5057827126352847
#  1.197634915434856 0.8155622775123004 ... 1.6900594385469203 1.3441926869850618
# 1.1976075477610117 0.9854194365620921 ...  1.517176750287323 1.4923755555870957
# 1.1976774991576093 0.7941478013312475 ... 1.7189774402208646 1.3267859858670348
# 1.1976001457972234 0.6955660434047215 ...  1.864132869823714 1.2386526451012345
# 1.1975582662169957 0.8207881389707098 ... 1.6847449580323444 1.3496048680469581
#                ...                ... ...                ...                ...
# 1.1975490049215385 0.9506047687209491 ...  1.549475111913947 1.4638391531856005
# 1.1976833782379415 0.8061246468166303 ... 1.7075484700630597  1.340269096775136
# 1.1976021988052235 0.8820705387216288 ... 1.6178309543643548  1.405233697751007
# 1.1977655120447779 0.9463631583852118 ... 1.5601854300618632 1.4665215852387605
# 1.1977579974274781 0.8540497632510055 ... 1.6533601247311875 1.3848194277917825
# 1.1974894196376875 0.9248939307585715 ... 1.5740567336625773 1.4419845401265876
# 1.1975242265390316 0.9833959974224095 ... 1.5211410459282386 1.4928219936420515
# 1.1976093294828807 0.7262608815361089 ... 1.8088393770500333 1.2623959749120668
# 1.1976742244336531 0.8349179674768509 ... 1.6720160568822122 1.3652788658591544
# 1.1976670152805464 0.8521952925622986 ... 1.6558326874534401 1.3834955221727614

# %%
t_sly_mon_bary_from_fit
# Out:
# <KNTable length=35392>
#     chirp_mass         mass_ratio     ...        mb1                mb2
#      float64            float64       ...      float64            float64
# ------------------ ------------------ ... ------------------ ------------------
# 1.1976132771415884 0.8570731407826855 ... 1.6435942165516335 1.3822527903789363
#  1.197558884773613 0.9588427941239721 ... 1.5463891629881912  1.475113261129336
# 1.1976058636220297 0.8332131586429111 ... 1.6712656535358834 1.3615965434884902
# 1.1976087016348054 0.9607416101483752 ... 1.5427825251002256 1.4749571027339712
# 1.1976795248898326 0.9987750971281013 ...  1.507855589985098 1.5057827126352847
#  1.197634915434856 0.8155622775123004 ... 1.6900594385469203 1.3441926869850618
# 1.1976075477610117 0.9854194365620921 ...  1.517176750287323 1.4923755555870957
# 1.1976774991576093 0.7941478013312475 ... 1.7189774402208646 1.3267859858670348
# 1.1976001457972234 0.6955660434047215 ...  1.864132869823714 1.2386526451012345
# 1.1975582662169957 0.8207881389707098 ... 1.6847449580323444 1.3496048680469581
#                ...                ... ...                ...                ...
# 1.1975490049215385 0.9506047687209491 ...  1.549475111913947 1.4638391531856005
# 1.1976833782379415 0.8061246468166303 ... 1.7075484700630597  1.340269096775136
# 1.1976021988052235 0.8820705387216288 ... 1.6178309543643548  1.405233697751007
# 1.1977655120447779 0.9463631583852118 ... 1.5601854300618632 1.4665215852387605
# 1.1977579974274781 0.8540497632510055 ... 1.6533601247311875 1.3848194277917825
# 1.1974894196376875 0.9248939307585715 ... 1.5740567336625773 1.4419845401265876
# 1.1975242265390316 0.9833959974224095 ... 1.5211410459282386 1.4928219936420515
# 1.1976093294828807 0.7262608815361089 ... 1.8088393770500333 1.2623959749120668
# 1.1976742244336531 0.8349179674768509 ... 1.6720160568822122 1.3652788658591544
# 1.1976670152805464 0.8521952925622986 ... 1.6558326874534401 1.3834955221727614

# %% [markdown]
# #### 1.2 Calculating Compactness

# %% [markdown]
# Let’s Demonstrate some of the differences between calculating compactness from
# - fit (i.e. being EOS agnostic) vs.
# - calculating it from an EOS.

# %%
from gwemlightcurves.KNModels import KNTable
from gwpy.table import EventTable
import matplotlib.pyplot as plt

#outdated
#from gwpy.plotter import EventTablePlot
#use instead
from gwpy.plot import Plot
#from gwpy.plotter import TimeSeriesPlot

# %%
t = KNTable.read_samples('posterior_samples.dat')
t = t.calc_tidal_lambda(remove_negative_lambda=True)
# Out:
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# /home/nina/anaconda3/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# You have requested to remove negative lambda values
# Removing 0/35392 due to negative lambdas

# %%
#plt.figure(figsize=(18.5, 10.5))
#plot = plt.subplots(figsize=(20, 10))
ax = plot.gca()
EOS = ['ap3', 'ap4', 'eng', 'gnh3', 'H4', 'mpa1', 'ms1', 'ms1b', 'sly', 'wff1', 'wff2']
Color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'chartreuse', 'burlywood', 'lightseagreen', 'mediumaquamarine', 'brown']
EOS_Color = dict(zip(EOS, Color))

# %%
for eos in EOS:
    t_radius = t.calc_radius(EOS=eos, TOV='Monica')
    t_radius_compact = t_radius.calc_compactness()
    t_radius_compact = EventTable(t_radius_compact)
    ax.hist(t_radius_compact['c1'], log=True, bins=20, alpha=0.5, histtype='stepfilled', label='Compactness From {0} Table'.format(eos), color=EOS_Color[eos])
# Out:
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS

# %%
t_comp_fit = t.calc_compactness(fit=True)
ax.hist(t_comp_fit['c1'], log=True, bins=20, alpha=0.2, histtype='stepfilled', label='Compactness From Fit', color='black')
# Out:
# You have chose to calculate compactness from fit.
# you are therefore choosing to be EOS agnostic
# (array([ 184.,  588., 1297., 2519., 3753., 4696., 5194., 4268., 3703.,
#         2940., 1971., 1341.,  979.,  706.,  359.,  581.,  126.,   83.,
#           21.,   83.]),
#  array([0.15286281, 0.15772228, 0.16258174, 0.1674412 , 0.17230067,
#         0.17716013, 0.18201959, 0.18687905, 0.19173852, 0.19659798,
#         0.20145744, 0.2063169 , 0.21117637, 0.21603583, 0.22089529,
#         0.22575476, 0.23061422, 0.23547368, 0.24033314, 0.24519261,
#         0.25005207]),
#  <a list of 1 Patch objects>)

# %%
ax.set_xlabel('Compactness')
ax.set_ylabel('Rate')
ax.set_title('Compactness Values')
plot.legend()
ax.autoscale(axis='x', tight=True)
plot.show()
# Out:
# <ipython-input-72-9b0a26b6681f>:6: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plot.show()

# %% [markdown]
# #### 1.3) Calculating Baryonic Mass

# %% [markdown]
# Let’s demonstrate some of the differences between calculating the **baryonic_mass**from
# - fit versus
# - calculating it from an EOS table.

# %%
from gwemlightcurves.KNModels import KNTable
from gwpy.table import EventTable
#from gwpy.plotter import EventTablePlot

t = KNTable.read_samples('posterior_samples.dat')
t_indepedent = KNTable.read_samples('posterior_samples.dat')

# calculate lamdba 1,2 for eos vs. fit (independent) version 
t = t.calc_tidal_lambda(remove_negative_lambda=True)
t_indepedent = t_indepedent.calc_tidal_lambda(remove_negative_lambda=True)

t = t.downsample(Nsamples=1000)
t_indepedent = t_indepedent.downsample(Nsamples=1000)
# Out:
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# You have requested to remove negative lambda values
# Removing 0/35392 due to negative lambdas
# You have requested to remove negative lambda values
# Removing 0/35392 due to negative lambdas
# You are requesting to downsample the number of posterior samples to 1000
# You are requesting to downsample the number of posterior samples to 1000

# %%
#plot = EventTablePlot(figsize=(18.5, 10.5))
EOS = ['ap3', 'ap4', 'eng', 'gnh3', 'H4', 'mpa1', 'ms1', 'ms1b', 'sly', 'wff1', 'wff2']
Color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'chartreuse', 'burlywood', 'lightseagreen', 'mediumaquamarine', 'brown']
locations = [(3,4,1), (3,4,2), (3,4,3), (3,4,4), (3,4,5), (3,4,6), (3,4,7), (3,4,8), (3,4,9), (3,4,10), (3,4,11)]
plot_location = dict(zip(EOS, locations))
EOS_Color = dict(zip(EOS, Color))

# %%
# calculate compactness C and baryonic mass mb for fit dependent version
t_indepedent = t_indepedent.calc_compactness(fit=True)
t_indepedent = t_indepedent.calc_baryonic_mass(EOS=None, TOV=None, fit=True)
# Out:
# You have chose to calculate compactness from fit.
# you are therefore choosing to be EOS agnostic

# %%
for eos in EOS:
    ax = plot.add_subplot(plot_location[eos][0], plot_location[eos][1], plot_location[eos][2])
    ax.set_title('EOS: {0}'.format(eos), fontsize='small')
    
    for fit in [True, False]:
        t_radius = t.calc_radius(EOS=eos, TOV='Monica')
        t_radius_compact = t_radius.calc_compactness()
        t_radius_compact_bary = t_radius_compact.calc_baryonic_mass(EOS=eos, TOV='Monica', fit=fit)
        t_radius_compact_bary = EventTable(t_radius_compact_bary)
        if fit:
            plot.add_scatter(t_radius_compact_bary['m1'], t_radius_compact_bary['mb1'], label='Bary From Fit', alpha=0.5, color=EOS_Color[eos], ax=ax)
        else:
            plot.add_scatter(t_radius_compact_bary['m1'], t_radius_compact_bary['mb1'], label='Bary From Table', alpha=0.5, color=EOS_Color[eos], marker='*', ax=ax)
    plot.add_scatter(t_indepedent['m1'], t_indepedent['mb1'], label='EOS Independent', alpha=0.2, color='grey', marker='+', ax=ax)
    plot.add_legend(loc="upper left", fancybox=True, fontsize='small')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-0bb1e2895080> in <module>
#       1 for eos in EOS:
# ----> 2     ax = plot.add_subplot(plot_location[eos][0], plot_location[eos][1], plot_location[eos][2])
#       3     ax.set_title('EOS: {0}'.format(eos), fontsize='small')
#       4
#       5     for fit in [True, False]:
#
# NameError: name 'plot' is not defined

# %%
plot.text(0.5, 0.04, 'Mass of Larger Object', ha='center', fontsize='x-large')
plot.text(0.04, 0.5, 'Baryonic Mass of Larger Object', va='center', rotation='vertical', fontsize='x-large')
plot.suptitle('Mass by Baryonic Mass of Larger Object', fontsize='x-large')
plot.show()

# %% [markdown]
# #### 1.4) Plotting the Ejecta Mass and Velocity of Ejecta

# %% [markdown]
# Now that we have compactness and the baryonic mass we can calculate **Mass of the ejecta** and the **velocity of the ejecta** using fits from Tim Dietrich and Maximiliano Ujevic.

# %% [markdown]
# The **dynamical ejecta mass fit formula** can be found

# %% [markdown]
# https://arxiv.org/pdf/1612.03665.pdf#equation.3.1

# %% [markdown]
# \begin{equation*}
# \frac{M_{ej}^{fit}}{10^{-3} M_{\odot}} = \left[a \Big( \frac{M_2}{M_1} \Big)^{1/3}  \Big( \frac{1 - 2C_1}{C_1} \Big) + b\Big( \frac{M_2}{M_1} \Big)^{n} + c \Big( 1- \frac{M_1}{M_1^*} \Big) \right] M_1^* + (1 \leftrightarrow 2) + d
# \label{eq:vector_ray} \tag{1}
# \end{equation*}

# %% [markdown]
# and the constants are taken from

# %% [markdown]
# https://arxiv.org/pdf/1612.03665.pdf#equation.3.2

# %%
a = −1.35695 
b = 6.11252
c = -49.43355 
d = 16.1144 
n = −2.5484

# %% [markdown]
# The method used to calculate in this repo is `gwemlightcurves.EjectaFits.DiUj2017.calc_meje()` and can be used as follows:

# %%
from gwemlightcurves.EjectaFits.DiUj2017 import calc_meje
from gwemlightcurves.KNModels import KNTable

t = KNTable.read_samples('posterior_samples.dat')
t = t.calc_tidal_lambda(remove_negative_lambda=True)
t_sly_mon = t.calc_radius(EOS='sly', TOV='Monica')
t_sly_mon = t_sly_mon.calc_compactness()
t_sly_mon = t_sly_mon.calc_baryonic_mass(EOS='sly', TOV='Monica')

# here use new function calc_meje()
t_sly_mon['mej'] = calc_meje(t_sly_mon['m1'], t_sly_mon['mb1'], t_sly_mon['c1'], t_sly_mon['m2'], t_sly_mon['mb2'], t_sly_mon['c2'])
# Out:
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# You have requested to remove negative lambda values
# Removing 0/35392 due to negative lambdas
# You have chose to calculate compactness from radius.
# you are therefore must have selected a EOS

# %%
# calculated values of Ejecta Mass in Msol already divided by 10^{-3}
t_sly_mon['mej']
# Out:
# <Column name='mej' dtype='float64' length=35392>
#  0.007152119433310748
# 0.0053606394244894665
#  0.007941537109621213
#  0.005351089412965521
#  0.005231558939381042
#  0.008640933701104319
#  0.005251622786303736
#  0.009638215231408334
#  0.017010049946048895
#  0.008423265791104232
#   0.01495884164300977
#  0.007332904099590937
#                   ...
#   0.01812522607533702
#  0.011277333193020413
#  0.005430823972404445
#  0.009062216213166902
#  0.006491893220344709
# 0.0054576515440691725
#  0.007238183839083893
#  0.005710959421869997
#  0.005252157581417334
#  0.014106081257905561
#  0.007878899843499649
#  0.007295191520800554

# %% [markdown]
# The **velocity of the ejecta mass** fit can be found:

# %% [markdown]
# https://arxiv.org/pdf/1612.03665.pdf#equation.3.9

# %% [markdown]
# \begin{equation*}
# v_{ej} = \sqrt{v_{\rho}^{2} + v_z^2}
# \label{eq:vector_ray} \tag{2}
# \end{equation*}

# %% [markdown]
# where $v_{\rho}$ is an EOS dependent fitting function by including a first order polynomial depending on the
# compactness $(1 + c C_{1,2})$, which leads to

# %% [markdown]
# \begin{equation*}
# v_{\rho} =  \left[ a \Big( \frac{M_1}{M_2} \Big) (1 + c C_1) \right] + (1 \leftrightarrow 2) + b
# \label{eq:vector_ray} \tag{2}
# \end{equation*}

# %% [markdown]
# where parameters are: $a = −0.219479, b = 0.444836$ and $ c = −2.67385$.

# %% [markdown]
# and $v_z$ is the velocity orthogonal to the orbital plane and is given as:

# %% [markdown]
# \begin{equation*}
# v_{z} =  \left[ a \Big( \frac{M_1}{M_2} \Big) (1 + c C_1) \right] + (1 \leftrightarrow 2) + b
# \label{eq:vector_ray} \tag{2}
# \end{equation*}

# %% [markdown]
# where parameters are $a = −0.315585$, $b = 0.63808$ and $c = −1.00757$.

# %% [markdown]
# The method used to calculate in this repo is `gwemlightcurves.EjectaFits.DiUj2017.calc_vej()` and can be used as follows:

# %%
from gwemlightcurves.EjectaFits.DiUj2017 import calc_vej
t_sly_mon['mej'] = calc_vej(t_sly_mon['m1'], t_sly_mon['c1'], t_sly_mon['m2'], t_sly_mon['c2'])

# %%
t_sly_mon['mej']
# Out:
# <Column name='mej' dtype='float64' length=35392>
# 0.23566018889658194
# 0.23763918565709902
# 0.23521410879458565
# 0.23738415676460808
#  0.2372638059262626
# 0.23449026436043818
# 0.23694504568624786
# 0.23424098540478033
# 0.23189090748527194
# 0.23475352479286063
# 0.23176656337605211
# 0.23585071390048395
#                 ...
# 0.23026123995101008
# 0.23312575046958633
# 0.23696031543000642
# 0.23505001546061874
# 0.23628889227100672
# 0.23788171947863032
# 0.23646552497882514
# 0.23678345297105544
#    0.23725592973827
# 0.23171726834711404
# 0.23562372628861905
# 0.23648101741450828

# %% [markdown]
# **Plot quantities $M_{ej}$ and $v_{ej}$**

# %%
from gwemlightcurves.EjectaFits.DiUj2017 import calc_meje, calc_vej
from gwemlightcurves.KNModels import KNTable
from gwpy.table import EventTable
#from gwpy.plotter import EventTablePlot

t = KNTable.read_samples('posterior_samples.dat')
t_indepedent = KNTable.read_samples('posterior_samples.dat')
t = t.calc_tidal_lambda(remove_negative_lambda=True)
t_indepedent = t_indepedent.calc_tidal_lambda(remove_negative_lambda=True)
t = t.downsample(Nsamples=1000)
t_indepedent = t_indepedent.downsample(Nsamples=1000)
# Out:
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# You have requested to remove negative lambda values
# Removing 0/35392 due to negative lambdas
# You have requested to remove negative lambda values
# Removing 0/35392 due to negative lambdas
# You are requesting to downsample the number of posterior samples to 1000
# You are requesting to downsample the number of posterior samples to 1000

# %%
#plot = EventTablePlot(figsize=(18.5, 10.5))
EOS = ['ap3', 'ap4', 'eng', 'gnh3', 'H4', 'mpa1', 'ms1', 'ms1b', 'sly', 'wff1', 'wff2']
Color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'chartreuse', 'burlywood', 'lightseagreen', 'mediumaquamarine', 'brown']
locations = [(3,4,1), (3,4,2), (3,4,3), (3,4,4), (3,4,5), (3,4,6), (3,4,7), (3,4,8), (3,4,9), (3,4,10), (3,4,11)]
plot_location = dict(zip(EOS, locations))
EOS_Color = dict(zip(EOS, Color))

# %%
t_indepedent = t_indepedent.calc_compactness(fit=True)
t_indepedent = t_indepedent.calc_baryonic_mass(EOS=None, TOV=None, fit=True)
t_indepedent['mej'] = calc_meje(t_indepedent['m1'], t_indepedent['mb1'], t_indepedent['c1'], t_indepedent['m2'], t_indepedent['mb2'], t_indepedent['c2'])
# Out:
# You have chose to calculate compactness from fit.
# you are therefore choosing to be EOS agnostic

# %%
for eos in EOS:
    ax = plot.add_subplot(plot_location[eos][0], plot_location[eos][1], plot_location[eos][2])
    ax.set_title('EOS: {0}'.format(eos), fontsize='small')
    for fit in [True, False]:
        t_radius = t.calc_radius(EOS=eos, TOV='Monica')
        t_radius_compact = t_radius.calc_compactness()
        t_radius_compact_bary = t_radius_compact.calc_baryonic_mass(EOS=eos, TOV='Monica', fit=fit)
        t_radius_compact_bary['mej'] = calc_meje(t_radius_compact_bary['m1'], t_radius_compact_bary['mb1'], t_radius_compact_bary['c1'], t_radius_compact_bary['m2'], t_radius_compact_bary['mb2'], t_radius_compact_bary['c2'])
        t_radius_compact_bary = EventTable(t_radius_compact_bary)
        if fit:
            plot.add_scatter(t_radius_compact_bary['m2'], t_radius_compact_bary['mej'], label='Bary From Fit', alpha=0.5, color=EOS_Color[eos], ax=ax)
        else:
            plot.add_scatter(t_radius_compact_bary['m2'], t_radius_compact_bary['mej'], label='Bary From Table', alpha=0.5, color=EOS_Color[eos], marker='*', ax=ax)
    plot.add_scatter(t_indepedent['m2'], t_indepedent['mej'], label='EOS Independent', alpha=0.2, color='grey', marker='+', ax=ax)
    plot.add_legend(loc="upper left", fancybox=True, fontsize='small')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-b14032789817> in <module>
#       1 for eos in EOS:
# ----> 2     ax = plot.add_subplot(plot_location[eos][0], plot_location[eos][1], plot_location[eos][2])
#       3     ax.set_title('EOS: {0}'.format(eos), fontsize='small')
#       4     for fit in [True, False]:
#       5         t_radius = t.calc_radius(EOS=eos, TOV='Monica')
#
# NameError: name 'plot' is not defined

# %%
plot.text(0.5, 0.04, 'Mass of Smaller Object', ha='center', fontsize='x-large')
plot.text(0.04, 0.5, 'Ejecta Mass', va='center', rotation='vertical', fontsize='x-large')
plot.suptitle('Smaller Mass by Ejecta Mass', fontsize='x-large')
plot.show()

# %% [markdown]
# #### 1.5) Generating Lightcurves

# %% [markdown]
# Finally, let’s **calculate a lightcurve** being **EOS agnostic**, meaning we calculate both the compactness and baryonic masses from fits.

# %% [markdown]
# Also let us look at:
# - Metzer 2017, and
# - DiUj2017<br>
#
# models.

# %% [markdown]
# In order to take a set of samples and calculate the light curves that would result from a realization of each sample, you can use the model which takes as inputs:
# - the string name of the model, and
# - the table of samples containing at minimum compactness and baryonic mass (it can calculate mass ejecta and velocity of ejecta on the fly).

# %%
from gwemlightcurves.KNModels import KNTable
from gwemlightcurves import lightcurve_utils

t = KNTable.read_samples('posterior_samples.dat')
t = t.calc_tidal_lambda(remove_negative_lambda=True)
t = t.calc_compactness(fit=True)
t = t.calc_baryonic_mass(EOS=None, TOV=None, fit=True)
t = t.downsample(Nsamples=100)

tini = 0.1;  # initial time
tmax = 50.0; # max. time
dt = 0.1;    # time step
vmin = 0.02; # min. velocity
th = 0.2;    # ??
ph = 3.14;   # ??
kappa = 1.0; # opacity
eps = 1.58*(10**10); # ??
alp = 1.2;   # ??
eth = 0.5;   # ?? thermal energy?
flgbct = 1;  # ??
beta = 3.0;  # ??
kappa_r = 1.0; # ??
slope_r = -1.2; # slope for what
theta_r = 0.0; # ??
Ye = 0.3 # electron fraction

# provides these values to keys
t['tini'] = tini; t['tmax'] = tmax; t['dt'] = dt; t['vmin'] = vmin; t['th'] = th; t['ph'] = ph; t['kappa'] = kappa; t['eps'] = eps; t['alp'] = alp; t['eth'] = eth; t['flgbct'] = flgbct; t['beta'] = beta; t['kappa_r'] = kappa_r; t['slope_r'] = slope_r; t['theta_r'] = theta_r; t['Ye'] = Ye
# Out:
# setting m1 to m1_source
# setting m2 to m2_source
# setting dlambdat to delta_lambda_tilde
# setting lambdat to lambda_tilde
# /home/nina/anaconda3/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# You have requested to remove negative lambda values
# Removing 0/35392 due to negative lambdas
# You have chose to calculate compactness from fit.
# you are therefore choosing to be EOS agnostic
# You are requesting to downsample the number of posterior samples to 100

# %%
# Create dict of tables for the various models, calculating mass ejecta velocity of ejecta and the lightcurve from the model
models = ["DiUj2017","Me2017"]
model_tables = {}
for model in models:
    model_tables[model] = KNTable.model(model, t)

# Now we need to do some interpolation
for model in models:
    model_tables[model] = lightcurve_utils.calc_peak_mags(model_tables[model])
    model_tables[model] = lightcurve_utils.interpolate_mags_lbol(model_tables[model])
# Out:
# /home/nina/anaconda3/lib/python3.8/site-packages/gwemlightcurves/KNModels/io/Me2017.py:264: RuntimeWarning: invalid value encountered in double_scalars
#   temp[j] = 1.0e10*(3.0*E[j]/(arad*4.0*np.pi*R[j]**(3.0)))**(0.25)
# /home/nina/anaconda3/lib/python3.8/site-packages/gwemlightcurves/KNModels/io/Me2017.py:314: RuntimeWarning: invalid value encountered in true_divide
#   Tobs = 1.0e10*(Ltot/(4.0*np.pi*(Rphoto)**(2.0)*sigSB))**(0.25)
# /home/nina/anaconda3/lib/python3.8/site-packages/gwemlightcurves/KNModels/io/Me2017.py:317: RuntimeWarning: divide by zero encountered in true_divide
#   expo = np.exp(h*nuobsarray/(kb*Tobs))-1.0
# /home/nina/anaconda3/lib/python3.8/site-packages/gwemlightcurves/KNModels/io/Me2017.py:320: RuntimeWarning: divide by zero encountered in log10
#   mAB = -2.5*np.log10(F) - 48.6
# /home/nina/anaconda3/lib/python3.8/site-packages/scipy/interpolate/interpolate.py:608: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /home/nina/anaconda3/lib/python3.8/site-packages/scipy/interpolate/interpolate.py:608: RuntimeWarning: invalid value encountered in add
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /home/nina/anaconda3/lib/python3.8/site-packages/gwemlightcurves/lightcurve_utils.py:661: RuntimeWarning: divide by zero encountered in log10
#   idx = np.where((~np.isnan(np.log10(lbol))) & ~(lbol==0))[0]

# %%
# NO DATA?!
#model_tables["DiUj2017"]

# %%
model_tables[models[1]]['lbol'][0]
# Out:
# array([0.00000000e+00, 6.25061126e+41, 4.95717554e+41, 4.62483496e+41,
#        4.28894501e+41, 3.95094937e+41, 3.62039762e+41, 3.30429182e+41,
#        3.00694261e+41, 2.73067361e+41, 2.47642099e+41, 2.24416907e+41,
#        2.03326195e+41, 1.84262865e+41, 1.67094689e+41, 1.51676238e+41,
#        1.37857465e+41, 1.25489765e+41, 1.14430086e+41, 1.04543583e+41,
#        9.57051601e+40, 8.78002017e+40, 8.07247252e+40, 7.43851309e+40,
#        6.86976896e+40, 6.35878708e+40, 5.89895887e+40, 5.48444190e+40,
#        5.11008258e+40, 4.77134205e+40, 4.46422702e+40, 4.18522616e+40,
#        3.93125244e+40, 3.69959141e+40, 3.48785508e+40, 3.29394122e+40,
#        3.11599741e+40, 2.95238961e+40, 2.80167458e+40, 2.66257589e+40,
#        2.53396300e+40, 2.41483299e+40, 2.30429477e+40, 2.20155528e+40,
#        2.10590752e+40, 2.01672013e+40, 1.93342830e+40, 1.85552592e+40,
#        1.78255865e+40, 1.71411796e+40, 1.64983584e+40, 1.58938024e+40,
#        1.53245108e+40, 1.47877666e+40, 1.42811064e+40, 1.38022927e+40,
#        1.33492902e+40, 1.29202447e+40, 1.25134643e+40, 1.21274030e+40,
#        1.17606463e+40, 1.14118975e+40, 1.10799673e+40, 1.07637624e+40,
#        1.04622771e+40, 1.01745848e+40, 9.89983090e+39, 9.63722610e+39,
#        9.38604058e+39, 9.14559873e+39, 8.91527446e+39, 8.69448690e+39,
#        8.48269654e+39, 8.27940179e+39, 8.08413583e+39, 7.89646375e+39,
#        7.71597998e+39, 7.54230597e+39, 7.37508805e+39, 7.21399548e+39,
#        7.05871872e+39, 6.90896778e+39, 6.76447082e+39, 6.62497273e+39,
#        6.49023396e+39, 6.36002937e+39, 6.23414722e+39, 6.11238819e+39,
#        5.99456455e+39, 5.88049933e+39, 5.77002560e+39, 5.66298579e+39,
#        5.55923106e+39, 5.45862074e+39, 5.36102177e+39, 5.26630821e+39,
#        5.17436082e+39, 5.08506659e+39, 4.99831838e+39, 4.91401453e+39,
#        4.83205857e+39, 4.75235884e+39, 4.67482825e+39, 4.59938400e+39,
#        4.52594731e+39, 4.45444318e+39, 4.38480022e+39, 4.31695037e+39,
#        4.25082878e+39, 4.18637359e+39, 4.12352576e+39, 4.06222895e+39,
#        4.00242933e+39, 3.94407548e+39, 3.88711822e+39, 3.83151056e+39,
#        3.77720749e+39, 3.72416596e+39, 3.67234473e+39, 3.62170430e+39,
#        3.57220682e+39, 3.52381598e+39, 3.47649698e+39, 3.43021640e+39,
#        3.38494219e+39, 3.34064356e+39, 3.29729094e+39, 3.25485590e+39,
#        3.21331113e+39, 3.17263037e+39, 3.13278834e+39, 3.09376073e+39,
#        3.05552413e+39, 3.01805602e+39, 2.98133468e+39, 2.94533919e+39,
#        2.91004941e+39, 2.87544589e+39, 2.84150989e+39, 2.80822333e+39,
#        2.77556876e+39, 2.74352934e+39, 2.71208881e+39, 2.68123146e+39,
#        2.65094211e+39, 2.62120612e+39, 2.59200929e+39, 2.56333794e+39,
#        2.53517880e+39, 2.50751905e+39, 2.48034629e+39, 2.45364852e+39,
#        2.42741410e+39, 2.40163179e+39, 2.37629067e+39, 2.35138019e+39,
#        2.32689012e+39, 2.30281052e+39, 2.27913180e+39, 2.25584460e+39,
#        2.23293990e+39, 2.21040892e+39, 2.18824314e+39, 2.16643430e+39,
#        2.14497437e+39, 2.12385557e+39, 2.10307032e+39, 2.08261129e+39,
#        2.06247134e+39, 2.04264353e+39, 2.02312111e+39, 2.00389753e+39,
#        1.98496643e+39, 1.96632159e+39, 1.94795701e+39, 1.92986681e+39,
#        1.91204529e+39, 1.89448689e+39, 1.87718623e+39, 1.86013802e+39,
#        1.84333716e+39, 1.82677865e+39, 1.81045763e+39, 1.79436938e+39,
#        1.77850929e+39, 1.76287285e+39, 1.74745570e+39, 1.73225356e+39,
#        1.71726227e+39, 1.70247777e+39, 1.68789611e+39, 1.67351343e+39,
#        1.65932596e+39, 1.64533004e+39, 1.63152207e+39, 1.61789855e+39,
#        1.60445609e+39, 1.59119133e+39, 1.57810103e+39, 1.56518202e+39,
#        1.55243118e+39, 1.53984549e+39, 1.52742199e+39, 1.51515779e+39,
#        1.50305006e+39, 1.49109604e+39, 1.47929303e+39, 1.46763840e+39,
#        1.45612956e+39, 1.44476399e+39, 1.43353924e+39, 1.42245289e+39,
#        1.41150258e+39, 1.40068600e+39, 1.39000091e+39, 1.37944509e+39,
#        1.36901639e+39, 1.35871268e+39, 1.34853192e+39, 1.33847206e+39,
#        1.32853113e+39, 1.31870719e+39, 1.30899834e+39, 1.29940272e+39,
#        1.28991851e+39, 1.28054393e+39, 1.27127722e+39, 1.26211669e+39,
#        1.25306064e+39, 1.24410744e+39, 1.23525549e+39, 1.22650319e+39,
#        1.21784901e+39, 1.20929144e+39, 1.20082898e+39, 1.19246018e+39,
#        1.18418361e+39, 1.17599788e+39, 1.16790161e+39, 1.15989345e+39,
#        1.15197210e+39, 1.14413624e+39, 1.13638461e+39, 1.12871597e+39,
#        1.12112909e+39, 1.11362278e+39, 1.10619586e+39, 1.09884717e+39,
#        1.09157557e+39, 1.08437997e+39, 1.07725926e+39, 1.07021238e+39,
#        1.06323827e+39, 1.05633589e+39, 1.04950425e+39, 1.04274233e+39,
#        1.03604916e+39, 1.02942378e+39, 1.02286525e+39, 1.01637264e+39,
#        1.00994504e+39, 1.00358156e+39, 9.97281319e+38, 9.91043450e+38,
#        9.84867109e+38, 9.78751461e+38, 9.72695688e+38, 9.66698985e+38,
#        9.60760562e+38, 9.54879640e+38, 9.49055455e+38, 9.43287257e+38,
#        9.37574306e+38, 9.31915877e+38, 9.26311255e+38, 9.20759739e+38,
#        9.15260638e+38, 9.09813272e+38, 9.04416976e+38, 8.99071091e+38,
#        8.93774971e+38, 8.88527982e+38, 8.83329498e+38, 8.78178905e+38,
#        8.73075597e+38, 8.68018979e+38, 8.63008466e+38, 8.58043480e+38,
#        8.53123456e+38, 8.48247834e+38, 8.43416066e+38, 8.38627611e+38,
#        8.33881936e+38, 8.29178518e+38, 8.24516841e+38, 8.19896398e+38,
#        8.15316689e+38, 8.10777221e+38, 8.06277510e+38, 8.01817079e+38,
#        7.97395459e+38, 7.93012186e+38, 7.88666805e+38, 7.84358868e+38,
#        7.80087932e+38, 7.75853562e+38, 7.71655329e+38, 7.67492811e+38,
#        7.63365592e+38, 7.59273262e+38, 7.55215417e+38, 7.51191659e+38,
#        7.47201596e+38, 7.43244842e+38, 7.39321016e+38, 7.35429743e+38,
#        7.31570652e+38, 7.27743381e+38, 7.23947569e+38, 7.20182862e+38,
#        7.16448913e+38, 7.12745376e+38, 7.09071912e+38, 7.05428189e+38,
#        7.01813875e+38, 6.98228647e+38, 6.94672183e+38, 6.91144168e+38,
#        6.87644292e+38, 6.84172245e+38, 6.80727727e+38, 6.77310438e+38,
#        6.73920083e+38, 6.70556373e+38, 6.67219020e+38, 6.63907743e+38,
#        6.60622262e+38, 6.57362303e+38, 6.54127595e+38, 6.50917869e+38,
#        6.47732863e+38, 6.44572315e+38, 6.41435969e+38, 6.38323571e+38,
#        6.35234872e+38, 6.32169624e+38, 6.29127584e+38, 6.26108512e+38,
#        6.23112171e+38, 6.20138326e+38, 6.17186747e+38, 6.14257206e+38,
#        6.11349477e+38, 6.08463339e+38, 6.05598573e+38, 6.02754962e+38,
#        5.99932293e+38, 5.97130354e+38, 5.94348938e+38, 5.91587839e+38,
#        5.88846855e+38, 5.86125785e+38, 5.83424431e+38, 5.80742598e+38,
#        5.78080094e+38, 5.75436727e+38, 5.72812310e+38, 5.70206658e+38,
#        5.67619586e+38, 5.65050915e+38, 5.62500464e+38, 5.59968057e+38,
#        5.57453521e+38, 5.54956682e+38, 5.52477371e+38, 5.50015419e+38,
#        5.47570660e+38, 5.45142931e+38, 5.42732068e+38, 5.40337913e+38,
#        5.37960307e+38, 5.35599093e+38, 5.33254118e+38, 5.30925228e+38,
#        5.28612273e+38, 5.26315104e+38, 5.24033574e+38, 5.21767538e+38,
#        5.19516851e+38, 5.17281372e+38, 5.15060961e+38, 5.12855478e+38,
#        5.10664786e+38, 5.08488751e+38, 5.06327238e+38, 5.04180114e+38,
#        5.02047250e+38, 4.99928516e+38, 4.97823783e+38, 4.95732926e+38,
#        4.93655819e+38, 4.91592340e+38, 4.89542365e+38, 4.87505775e+38,
#        4.85482450e+38, 4.83472273e+38, 4.81475125e+38, 4.79490893e+38,
#        4.77519462e+38, 4.75560719e+38, 4.73614553e+38, 4.71680854e+38,
#        4.69759512e+38, 4.67850420e+38, 4.65953471e+38, 4.64068560e+38,
#        4.62195583e+38, 4.60334436e+38, 4.58485017e+38, 4.56647226e+38,
#        4.54820962e+38, 4.53006127e+38, 4.51202624e+38, 4.49410355e+38,
#        4.47629226e+38, 4.45859142e+38, 4.44100009e+38, 4.42351734e+38,
#        4.40614228e+38, 4.38887398e+38, 4.37171155e+38, 4.35465411e+38,
#        4.33770078e+38, 4.32085070e+38, 4.30410300e+38, 4.28745684e+38,
#        4.27091138e+38, 4.25446578e+38, 4.23811923e+38, 4.22187091e+38,
#        4.20572001e+38, 4.18966574e+38, 4.17370730e+38, 4.15784393e+38,
#        4.14207484e+38, 4.12639927e+38, 4.11081646e+38, 4.09532567e+38,
#        4.07992616e+38, 4.06461718e+38, 4.04939802e+38, 4.03426796e+38,
#        4.01922627e+38, 4.00427227e+38, 3.98940525e+38, 3.97462452e+38,
#        3.95992940e+38, 3.94531922e+38, 3.93079329e+38, 3.91635097e+38,
#        3.90199159e+38, 3.88771451e+38, 3.87351907e+38, 3.85940466e+38,
#        3.84537062e+38, 3.83141634e+38, 3.81754121e+38, 3.80374460e+38,
#        3.79002591e+38, 3.77638455e+38, 3.76281992e+38, 3.74933142e+38,
#        3.73591849e+38, 3.72258053e+38, 3.70931698e+38, 3.69612727e+38,
#        3.68301084e+38, 3.66996714e+38, 3.65699562e+38, 3.64409572e+38,
#        3.63126692e+38, 3.61850868e+38, 3.60582047e+38, 3.59320176e+38,
#        3.58065203e+38, 3.56817078e+38, 3.55575749e+38, 3.54341166e+38,
#        3.53113279e+38, 3.51892038e+38, 3.50677394e+38, 3.49469299e+38,
#        3.48267704e+38, 3.47072562e+38, 3.45883826e+38, 3.44701448e+38,
#        3.43525383e+38, 3.42355584e+38, 3.41192007e+38, 0.00000000e+00])

# %%
# access single vals in lbol for first sample of lbol
lbol = model_tables[models[1]]['lbol'][0]
print(lbol[0], lbol[5], lbol[7])
# Out:
# 0.0 3.950949368554617e+41 3.304291815945758e+41

# %%
model_tables["Me2017"]
# Out:
# <KNTable length=100>
#     chirp_mass         mass_ratio     ...        mag_K [500]
#      float64            float64       ...          float64
# ------------------ ------------------ ... -------------------------
#  1.197663941135797 0.7315385974668871 ...  nan .. 24.23651678055942
# 1.1975810755139449 0.8026177533710678 ... nan .. 29.336089115796263
# 1.1975120175905936 0.8051202949830965 ...  nan .. 31.48316790923392
# 1.1975770337495255 0.9939365347700403 ...  nan .. 38.64864753275804
# 1.1975396397189793 0.9104755712392351 ...  nan .. 36.67698007870572
# 1.1975430724292746 0.7477447718915768 ... nan .. 26.933143324858996
# 1.1976746045365065 0.8416807379048826 ... nan .. 31.308300935270587
# 1.1976112505171363 0.9285004735919049 ... nan .. 36.963522925632624
# 1.1976725446269014 0.8215060660760969 ...  nan .. 30.65526150158083
# 1.1974938484342654 0.7789294948793428 ... nan .. 30.143106473061728
#                ...                ... ...                       ...
# 1.1976345147165632 0.7796997485630331 ... nan .. 28.592590338942607
# 1.1975963505437497 0.7591781040669833 ...  nan .. 26.85986013774879
# 1.1975892823429826 0.9584181541734225 ...  nan .. 38.20647945673935
# 1.1975501538082935 0.9781410533396835 ... nan .. 39.290514190285386
# 1.1976176611744456 0.7207324436993388 ... nan .. 23.112155196356092
#  1.197564170888122 0.9507336244876987 ...  nan .. 39.63806943583122
# 1.1976101723503025 0.6917281013723037 ... nan .. 22.691846994065536
# 1.1976421545839815 0.8359303377956309 ...  nan .. 32.65206440190578
#  1.197512756207036  0.994721000104766 ...   nan .. 41.5642584281485
# 1.1977162843159879  0.733853520188967 ... nan .. 22.231436060165812

# %%
import gwemlightcurves
gwemlightcurves.__file__
# Out:
# '/home/nina/anaconda3/lib/python3.8/site-packages/gwemlightcurves/__init__.py'

# %%
from gwemlightcurves.KNModels import table

distance = 100 #Mpc
plot = KNTable.plot_mag_panels(model_tables, distance=distance)
plot.show()
# Out:
# <ipython-input-63-31890087ef60>:5: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plot.show()

# %% [markdown]
# # <span style="color:orange"> 2) Lightcurves </span>

# %% [markdown]
# #  <span style="color:red"> 3) Equation of State </span>

# %% [markdown]
# Depending on how you solve the TOV equation, which describes a non-rotating neutron star (NS) in hydrostatic equilibrium, you will end up with different NS parameters. The nominal two parameters used to illustrate differences in equation of state (EOS) are:
# - mass and
# - radius

# %% [markdown]
# #### 3.1) Mass-Radius Curves

# %% [markdown]
# For a subset of EOSs, we can plot mass radius curves.

# %%
from distutils.spawn import find_executable
from gwemlightcurves.KNModels import table
from gwpy.table import EventTable
from gwpy.plot import Plot
#from gwpy.plot import EventTablePlot
#from gwpy.plot import TimeSeriesPlot

# %%
#plot = EventTablePlot(figsize=(18.5, 10.5))

# %%
fig = EventTablePlot(figsize=(18.5, 10.5))
ax = fig.gca()
EOS = ['ap3', 'ap4', 'eng', 'gnh3', 'H4', 'mpa1', 'ms1', 'ms1b', 'sly', 'wff1', 'wff2']
Color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'chartreuse', 'burlywood', 'lightseagreen', 'mediumaquamarine', 'brown']
EOS_Color = dict(zip(EOS, Color))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-158595651353> in <module>
# ----> 1 fig = EventTablePlot(figsize=(18.5, 10.5))
#       2 ax = fig.gca()
#       3 EOS = ['ap3', 'ap4', 'eng', 'gnh3', 'H4', 'mpa1', 'ms1', 'ms1b', 'sly', 'wff1', 'wff2']
#       4 Color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'chartreuse', 'burlywood', 'lightseagreen', 'mediumaquamarine', 'brown']
#       5 EOS_Color = dict(zip(EOS, Color))
#
# NameError: name 'EventTablePlot' is not defined

# %%
for eos in EOS:
    t=EventTable.read(find_executable(eos+'_mr.dat'), format='ascii')
    mask=t['radius']<20
    ax.fig(t['radius'][mask], t['mass'][mask], color=EOS_Color[eos], label=eos)

ax.set_xlabel("Radius (km)")
ax.set_ylabel("Mass ($M_{\odot}$)")
ax.set_title('Monica Mass Radius Curves')
fig.add_legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-11bcf53f99d2> in <module>
#       2     t=EventTable.read(find_executable(eos+'_mr.dat'), format='ascii')
#       3     mask=t['radius']<20
# ----> 4     ax.fig(t['radius'][mask], t['mass'][mask], color=EOS_Color[eos], label=eos)
#       5 ax.set_xlabel("Radius (km)")
#       6 ax.set_ylabel("Mass ($M_{\odot}$)")
#
# AttributeError: 'AxesSubplot' object has no attribute 'fig'

# %% [markdown]
# #### 3.2 ) Maximum NS Mass

# %% [markdown]
# Each equation of state has a maximum allowed mass. This, along with several other constraints arising from causality and limitations on spin, determine what masses and radii are allowed for NSs.

# %% [markdown]
# #### 3.3) EOS From Polytropes:

# %% [markdown]
# LALSimulation also has the capability to construct an EOS using a set of 4 polytrope parameters, as in Read et al.

# %% [markdown]
# #### 3.4) Direct Comparison

# %% [markdown]
# Here we plot a direct comparison of mass radius curves from the three different TOV solvers.

# %%
from distutils.spawn import find_executable
from gwemlightcurves.KNModels import table
from gwpy.table import EventTable
#from gwpy.plotter import EventTablePlot
import astropy.units as u
import astropy.constants as C


G = C.G.value; c = C.c.value; msun = u.M_sun.to(u.kg)

# %%
#plot = EventTablePlot(figsize=(20.5, 10.5))
EOS = ['ap4', 'H4', 'ms1b']
Color = ['blue', 'green', 'red']
locations = [(1,3,1), (1,3,2), (1,3,3)]
plot_location = dict(zip(EOS, locations))

# %%
for eos in EOS:
    ax = plot.add_subplot(plot_location[eos][0], plot_location[eos][1], plot_location[eos][2])
    ax.set_title('EOS: {0}'.format(eos), fontsize='small')
    t_mon=EventTable.read(find_executable(eos+'_mr.dat'), format='ascii')
    t_wk=EventTable.read(find_executable(eos+'.tidal.seq'), format='ascii')
    t_lalsim=EventTable.read(find_executable(eos+'_lalsim_mr.dat'), format='ascii')
    wk_conversion=(msun * G / c**2)*10**-3
    mask_mon=t_mon['radius']<20
    mask_wk=t_wk['Circumferential_radius']<20
    mask_lalsim=t_lalsim['radius']<20
    plot.add_scatter(t_mon['radius'][mask_mon], t_mon['mass'][mask_mon], label='Monica '+eos ,color=Color[0], ax=ax)
    plot.add_scatter(t_wk['Circumferential_radius'][mask_wk]*wk_conversion, t_wk['grav_mass'][mask_wk], label='Wolfgang '+eos ,color=Color[1], ax=ax)
    plot.add_scatter(t_lalsim['radius'][mask_lalsim], t_lalsim['mass'][mask_lalsim], label='lalsim '+eos ,color=Color[2], ax=ax)
    plot.add_legend(loc="upper left", fancybox=True, fontsize='small')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-24dae97a3fec> in <module>
#       1 for eos in EOS:
# ----> 2     ax = plot.add_subplot(plot_location[eos][0], plot_location[eos][1], plot_location[eos][2])
#       3     ax.set_title('EOS: {0}'.format(eos), fontsize='small')
#       4     t_mon=EventTable.read(find_executable(eos+'_mr.dat'), format='ascii')
#       5     t_wk=EventTable.read(find_executable(eos+'.tidal.seq'), format='ascii')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'add_subplot'

# %%
plot.text(0.5, 0.04, 'Radius (km)', ha='center', fontsize='x-large')
plot.text(0.04, 0.5, 'Mass ($M_{\odot}$)', va='center', rotation='vertical', fontsize='x-large')
plot.suptitle('Mass-Radius Curve Comparison', fontsize='x-large')
